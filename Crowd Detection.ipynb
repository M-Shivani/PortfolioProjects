# %%
import os
import csv
import cv2
import torch
import numpy as np
import pandas as pd
from collections import defaultdict

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from ultralytics import YOLO
from scipy.spatial import distance
from collections import deque
import matplotlib.pyplot as plt

VIDEO_PATH = '/content/drive/MyDrive/Task 3/dataset_video.mp4'  # Your confirmed video path
DISTANCE_THRESHOLD = 150      # Distance in pixels to consider people "close"
PERSISTENCE_FRAMES = 3        # Number of consecutive frames with crowd to log
CONFIDENCE_THRESHOLD = 0.3    # Minimum detection confidence to consider person

model = YOLO('yolov8n.pt')

csv_file = 'crowd_log.csv'
with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Frame Number", "Person Count in Crowd"])

cap = cv2.VideoCapture(VIDEO_PATH)
if not cap.isOpened():
    print("❌ Failed to open video.")
    exit()

frame_count = 0
crowd_frame_buffer = deque(maxlen=PERSISTENCE_FRAMES)
debug_frames = []
frame_sample_limit = 5  # Number of sample frames to store for visualization

while True:
    ret, frame = cap.read()
    if not ret:
        print("❌ Failed to read frame.")
        break

    frame_count += 1

    results = model(frame, verbose=False)[0]
    detected_boxes_raw = []

    for box in results.boxes.data.tolist():
        x1, y1, x2, y2, conf, cls = box
        if int(cls) == 0 and conf > CONFIDENCE_THRESHOLD:
            xc = (x1 + x2) / 2
            yc = (y1 + y2) / 2
            w = x2 - x1
            h = y2 - y1
            detected_boxes_raw.append([xc, yc, w, h])

    boxes = [[xc - w / 2, yc - h / 2, xc + w / 2, yc + h / 2] for xc, yc, w, h in detected_boxes_raw]
    centers = [((x1 + x2) / 2, (y1 + y2) / 2) for x1, y1, x2, y2 in boxes]

    if len(centers) < 2:
        print(f"Frame {frame_count}: Not enough people detected ({len(centers)}).")
        crowd_frame_buffer.clear()
        continue

    dist_matrix = distance.cdist(centers, centers)
    close_map = dist_matrix < DISTANCE_THRESHOLD

    groups = []
    visited = set()
    for i in range(len(centers)):
        if i in visited:
            continue
        group = set([i])
        queue = [i]
        while queue:
            current = queue.pop()
            visited.add(current)
            for j in range(len(centers)):
                if j not in visited and close_map[current][j]:
                    group.add(j)
                    queue.append(j)
        if len(group) >= 3:
            groups.append(group)

    if groups:
        largest_crowd_size = max(len(g) for g in groups)
        print(f"[✓] Frame {frame_count}: Crowd detected with {largest_crowd_size} people")
        crowd_frame_buffer.append((frame_count, largest_crowd_size))

        if len(debug_frames) < frame_sample_limit:
            for x1, y1, x2, y2 in boxes:
                cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
            debug_frames.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    else:
        print(f"[✗] Frame {frame_count}: No crowd detected")
        crowd_frame_buffer.clear()

    if len(crowd_frame_buffer) == PERSISTENCE_FRAMES:
        logged_frame, logged_count = crowd_frame_buffer[0]
        with open(csv_file, mode='a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow([logged_frame, logged_count])
        print(f"[✓] Logged crowd event at frame {logged_frame} with {logged_count} people.")
        crowd_frame_buffer.clear()

cap.release()

for i, frame_img in enumerate(debug_frames):
    plt.figure(figsize=(10, 6))
    plt.imshow(frame_img)
    plt.title(f"Sample Frame {i + 1} with Detections")
    plt.axis('off')
    plt.show()

print("\n=== Logged Crowd Events ===")
with open(csv_file, mode='r') as file:
    reader = csv.reader(file)
    next(reader)
    for row in reader:
        print(f"Frame {row[0]} → Crowd Size: {row[1]}")
# Out:
# [✓] Frame 1: Crowd detected with 8 people
# [✓] Frame 2: Crowd detected with 9 people
# [✓] Frame 3: Crowd detected with 9 people
# [✓] Logged crowd event at frame 1 with 8 people.
# [✓] Frame 4: Crowd detected with 9 people
# [✓] Frame 5: Crowd detected with 9 people
# [✓] Frame 6: Crowd detected with 9 people
# [✓] Logged crowd event at frame 4 with 9 people.
# [✓] Frame 7: Crowd detected with 9 people
# [✓] Frame 8: Crowd detected with 9 people
# [✓] Frame 9: Crowd detected with 9 people
# [✓] Logged crowd event at frame 7 with 9 people.
# [✓] Frame 10: Crowd detected with 9 people
# [✓] Frame 11: Crowd detected with 9 people
# [✓] Frame 12: Crowd detected with 9 people
# [✓] Logged crowd event at frame 10 with 9 people.
# [✓] Frame 13: Crowd detected with 11 people
# [✓] Frame 14: Crowd detected with 11 people
# [✓] Frame 15: Crowd detected with 6 people
# [✓] Logged crowd event at frame 13 with 11 people.
# [✓] Frame 16: Crowd detected with 6 people
# [✓] Frame 17: Crowd detected with 6 people
# [✓] Frame 18: Crowd detected with 6 people
# [✓] Logged crowd event at frame 16 with 6 people.
# [✓] Frame 19: Crowd detected with 10 people
# [✓] Frame 20: Crowd detected with 7 people
# [✓] Frame 21: Crowd detected with 7 people
# [✓] Logged crowd event at frame 19 with 10 people.
# [✓] Frame 22: Crowd detected with 10 people
# [✓] Frame 23: Crowd detected with 8 people
# [✓] Frame 24: Crowd detected with 10 people
# [✓] Logged crowd event at frame 22 with 10 people.
# [✓] Frame 25: Crowd detected with 8 people
# [✓] Frame 26: Crowd detected with 8 people
# [✓] Frame 27: Crowd detected with 12 people
# [✓] Logged crowd event at frame 25 with 8 people.
# [✓] Frame 28: Crowd detected with 14 people
# [✓] Frame 29: Crowd detected with 13 people
# [✓] Frame 30: Crowd detected with 12 people
# [✓] Logged crowd event at frame 28 with 14 people.
# [✓] Frame 31: Crowd detected with 7 people
# [✓] Frame 32: Crowd detected with 13 people
# [✓] Frame 33: Crowd detected with 8 people
# [✓] Logged crowd event at frame 31 with 7 people.
# [✓] Frame 34: Crowd detected with 13 people
# [✓] Frame 35: Crowd detected with 5 people
# [✓] Frame 36: Crowd detected with 5 people
# [✓] Logged crowd event at frame 34 with 13 people.
# [✓] Frame 37: Crowd detected with 5 people
# [✓] Frame 38: Crowd detected with 8 people
# [✓] Frame 39: Crowd detected with 8 people
# [✓] Logged crowd event at frame 37 with 5 people.
# [✓] Frame 40: Crowd detected with 7 people
# [✓] Frame 41: Crowd detected with 7 people
# [✓] Frame 42: Crowd detected with 6 people
# [✓] Logged crowd event at frame 40 with 7 people.
# [✓] Frame 43: Crowd detected with 6 people
# [✓] Frame 44: Crowd detected with 8 people
# [✓] Frame 45: Crowd detected with 6 people
# [✓] Logged crowd event at frame 43 with 6 people.
# [✓] Frame 46: Crowd detected with 8 people
# [✓] Frame 47: Crowd detected with 7 people
# [✓] Frame 48: Crowd detected with 5 people
# [✓] Logged crowd event at frame 46 with 8 people.
# [✓] Frame 49: Crowd detected with 6 people
# [✓] Frame 50: Crowd detected with 7 people
# [✓] Frame 51: Crowd detected with 6 people
# [✓] Logged crowd event at frame 49 with 6 people.
# [✓] Frame 52: Crowd detected with 6 people
# [✓] Frame 53: Crowd detected with 7 people
# [✓] Frame 54: Crowd detected with 6 people
# [✓] Logged crowd event at frame 52 with 6 people.
# [✓] Frame 55: Crowd detected with 7 people
# [✓] Frame 56: Crowd detected with 6 people
# [✓] Frame 57: Crowd detected with 6 people
# [✓] Logged crowd event at frame 55 with 7 people.
# [✓] Frame 58: Crowd detected with 6 people
# [✓] Frame 59: Crowd detected with 7 people
# [✓] Frame 60: Crowd detected with 8 people
# [✓] Logged crowd event at frame 58 with 6 people.
# [✓] Frame 61: Crowd detected with 6 people
# [✓] Frame 62: Crowd detected with 6 people
# [✓] Frame 63: Crowd detected with 6 people
# [✓] Logged crowd event at frame 61 with 6 people.
# [✓] Frame 64: Crowd detected with 6 people
# [✓] Frame 65: Crowd detected with 6 people
# [✓] Frame 66: Crowd detected with 6 people
# [✓] Logged crowd event at frame 64 with 6 people.
# [✓] Frame 67: Crowd detected with 6 people
# [✓] Frame 68: Crowd detected with 6 people
# [✓] Frame 69: Crowd detected with 7 people
# [✓] Logged crowd event at frame 67 with 6 people.
# [✓] Frame 70: Crowd detected with 6 people
# [✓] Frame 71: Crowd detected with 7 people
# [✓] Frame 72: Crowd detected with 6 people
# [✓] Logged crowd event at frame 70 with 6 people.
# [✓] Frame 73: Crowd detected with 7 people
# [✓] Frame 74: Crowd detected with 7 people
# [✓] Frame 75: Crowd detected with 7 people
# [✓] Logged crowd event at frame 73 with 7 people.
# [✓] Frame 76: Crowd detected with 7 people
# [✓] Frame 77: Crowd detected with 7 people
# [✓] Frame 78: Crowd detected with 7 people
# [✓] Logged crowd event at frame 76 with 7 people.
# [✓] Frame 79: Crowd detected with 7 people
# [✓] Frame 80: Crowd detected with 7 people
# [✓] Frame 81: Crowd detected with 7 people
# [✓] Logged crowd event at frame 79 with 7 people.
# [✓] Frame 82: Crowd detected with 8 people
# [✓] Frame 83: Crowd detected with 7 people
# [✓] Frame 84: Crowd detected with 7 people
# [✓] Logged crowd event at frame 82 with 8 people.
# [✓] Frame 85: Crowd detected with 6 people
# [✓] Frame 86: Crowd detected with 7 people
# [✓] Frame 87: Crowd detected with 4 people
# [✓] Logged crowd event at frame 85 with 6 people.
# [✓] Frame 88: Crowd detected with 4 people
# [✓] Frame 89: Crowd detected with 7 people
# [✓] Frame 90: Crowd detected with 7 people
# [✓] Logged crowd event at frame 88 with 4 people.
# [✓] Frame 91: Crowd detected with 8 people
# [✓] Frame 92: Crowd detected with 7 people
# [✓] Frame 93: Crowd detected with 7 people
# [✓] Logged crowd event at frame 91 with 8 people.
# [✓] Frame 94: Crowd detected with 7 people
# [✓] Frame 95: Crowd detected with 7 people
# [✓] Frame 96: Crowd detected with 7 people
# [✓] Logged crowd event at frame 94 with 7 people.
# [✓] Frame 97: Crowd detected with 7 people
# [✓] Frame 98: Crowd detected with 7 people
# [✓] Frame 99: Crowd detected with 7 people
# [✓] Logged crowd event at frame 97 with 7 people.
# [✓] Frame 100: Crowd detected with 7 people
# [✓] Frame 101: Crowd detected with 7 people
# [✓] Frame 102: Crowd detected with 4 people
# [✓] Logged crowd event at frame 100 with 7 people.
# [✓] Frame 103: Crowd detected with 5 people
# [✓] Frame 104: Crowd detected with 5 people
# [✓] Frame 105: Crowd detected with 5 people
# [✓] Logged crowd event at frame 103 with 5 people.
# [✓] Frame 106: Crowd detected with 6 people
# [✓] Frame 107: Crowd detected with 6 people
# [✓] Frame 108: Crowd detected with 6 people
# [✓] Logged crowd event at frame 106 with 6 people.
# [✓] Frame 109: Crowd detected with 6 people
# [✓] Frame 110: Crowd detected with 6 people
# [✓] Frame 111: Crowd detected with 6 people
# [✓] Logged crowd event at frame 109 with 6 people.
# [✓] Frame 112: Crowd detected with 6 people
# [✓] Frame 113: Crowd detected with 6 people
# [✓] Frame 114: Crowd detected with 6 people
# [✓] Logged crowd event at frame 112 with 6 people.
# [✓] Frame 115: Crowd detected with 6 people
# [✓] Frame 116: Crowd detected with 6 people
# [✓] Frame 117: Crowd detected with 6 people
# [✓] Logged crowd event at frame 115 with 6 people.
# [✓] Frame 118: Crowd detected with 6 people
# [✓] Frame 119: Crowd detected with 6 people
# [✓] Frame 120: Crowd detected with 6 people
# [✓] Logged crowd event at frame 118 with 6 people.
# [✓] Frame 121: Crowd detected with 6 people
# [✓] Frame 122: Crowd detected with 6 people
# [✓] Frame 123: Crowd detected with 6 people
# [✓] Logged crowd event at frame 121 with 6 people.
# [✓] Frame 124: Crowd detected with 6 people
# [✓] Frame 125: Crowd detected with 6 people
# [✓] Frame 126: Crowd detected with 6 people
# [✓] Logged crowd event at frame 124 with 6 people.
# [✓] Frame 127: Crowd detected with 6 people
# [✓] Frame 128: Crowd detected with 6 people
# [✓] Frame 129: Crowd detected with 6 people
# [✓] Logged crowd event at frame 127 with 6 people.
# [✓] Frame 130: Crowd detected with 6 people
# [✓] Frame 131: Crowd detected with 6 people
# [✓] Frame 132: Crowd detected with 6 people
# [✓] Logged crowd event at frame 130 with 6 people.
# [✓] Frame 133: Crowd detected with 6 people
# [✓] Frame 134: Crowd detected with 6 people
# [✓] Frame 135: Crowd detected with 6 people
# [✓] Logged crowd event at frame 133 with 6 people.
# [✓] Frame 136: Crowd detected with 6 people
# [✓] Frame 137: Crowd detected with 6 people
# [✓] Frame 138: Crowd detected with 6 people
# [✓] Logged crowd event at frame 136 with 6 people.
# [✓] Frame 139: Crowd detected with 6 people
# [✓] Frame 140: Crowd detected with 6 people
# [✓] Frame 141: Crowd detected with 6 people
# [✓] Logged crowd event at frame 139 with 6 people.
# [✓] Frame 142: Crowd detected with 6 people
# [✓] Frame 143: Crowd detected with 6 people
# [✓] Frame 144: Crowd detected with 6 people
# [✓] Logged crowd event at frame 142 with 6 people.
# [✓] Frame 145: Crowd detected with 6 people
# [✓] Frame 146: Crowd detected with 6 people
# [✓] Frame 147: Crowd detected with 6 people
# [✓] Logged crowd event at frame 145 with 6 people.
# [✓] Frame 148: Crowd detected with 6 people
# [✓] Frame 149: Crowd detected with 6 people
# [✓] Frame 150: Crowd detected with 6 people
# [✓] Logged crowd event at frame 148 with 6 people.
# [✓] Frame 151: Crowd detected with 6 people
# [✓] Frame 152: Crowd detected with 6 people
# [✓] Frame 153: Crowd detected with 5 people
# [✓] Logged crowd event at frame 151 with 6 people.
# [✓] Frame 154: Crowd detected with 5 people
# [✓] Frame 155: Crowd detected with 5 people
# [✓] Frame 156: Crowd detected with 4 people
# [✓] Logged crowd event at frame 154 with 5 people.
# [✓] Frame 157: Crowd detected with 4 people
# [✓] Frame 158: Crowd detected with 4 people
# [✓] Frame 159: Crowd detected with 4 people
# [✓] Logged crowd event at frame 157 with 4 people.
# [✓] Frame 160: Crowd detected with 4 people
# [✓] Frame 161: Crowd detected with 4 people
# [✓] Frame 162: Crowd detected with 4 people
# [✓] Logged crowd event at frame 160 with 4 people.
# [✓] Frame 163: Crowd detected with 4 people
# [✓] Frame 164: Crowd detected with 4 people
# [✓] Frame 165: Crowd detected with 4 people
# [✓] Logged crowd event at frame 163 with 4 people.
# [✓] Frame 166: Crowd detected with 4 people
# [✓] Frame 167: Crowd detected with 4 people
# [✓] Frame 168: Crowd detected with 4 people
# [✓] Logged crowd event at frame 166 with 4 people.
# [✓] Frame 169: Crowd detected with 4 people
# [✓] Frame 170: Crowd detected with 4 people
# [✓] Frame 171: Crowd detected with 4 people
# [✓] Logged crowd event at frame 169 with 4 people.
# [✓] Frame 172: Crowd detected with 5 people
# [✓] Frame 173: Crowd detected with 5 people
# [✓] Frame 174: Crowd detected with 5 people
# [✓] Logged crowd event at frame 172 with 5 people.
# [✓] Frame 175: Crowd detected with 5 people
# [✓] Frame 176: Crowd detected with 6 people
# [✓] Frame 177: Crowd detected with 6 people
# [✓] Logged crowd event at frame 175 with 5 people.
# [✓] Frame 178: Crowd detected with 4 people
# [✓] Frame 179: Crowd detected with 5 people
# [✓] Frame 180: Crowd detected with 4 people
# [✓] Logged crowd event at frame 178 with 4 people.
# [✓] Frame 181: Crowd detected with 5 people
# [✓] Frame 182: Crowd detected with 5 people
# [✓] Frame 183: Crowd detected with 5 people
# [✓] Logged crowd event at frame 181 with 5 people.
# [✓] Frame 184: Crowd detected with 5 people
# [✓] Frame 185: Crowd detected with 5 people
# [✓] Frame 186: Crowd detected with 5 people
# [✓] Logged crowd event at frame 184 with 5 people.
# [✓] Frame 187: Crowd detected with 5 people
# [✓] Frame 188: Crowd detected with 4 people
# [✓] Frame 189: Crowd detected with 4 people
# [✓] Logged crowd event at frame 187 with 5 people.
# [✓] Frame 190: Crowd detected with 4 people
# [✓] Frame 191: Crowd detected with 4 people
# [✓] Frame 192: Crowd detected with 4 people
# [✓] Logged crowd event at frame 190 with 4 people.
# [✓] Frame 193: Crowd detected with 5 people
# [✓] Frame 194: Crowd detected with 5 people
# [✓] Frame 195: Crowd detected with 5 people
# [✓] Logged crowd event at frame 193 with 5 people.
# [✓] Frame 196: Crowd detected with 5 people
# [✓] Frame 197: Crowd detected with 6 people
# [✓] Frame 198: Crowd detected with 5 people
# [✓] Logged crowd event at frame 196 with 5 people.
# [✓] Frame 199: Crowd detected with 6 people
# [✓] Frame 200: Crowd detected with 6 people
# [✓] Frame 201: Crowd detected with 6 people
# [✓] Logged crowd event at frame 199 with 6 people.
# [✓] Frame 202: Crowd detected with 5 people
# [✓] Frame 203: Crowd detected with 6 people
# [✓] Frame 204: Crowd detected with 5 people
# [✓] Logged crowd event at frame 202 with 5 people.
# [✓] Frame 205: Crowd detected with 7 people
# [✓] Frame 206: Crowd detected with 6 people
# [✓] Frame 207: Crowd detected with 3 people
# [✓] Logged crowd event at frame 205 with 7 people.
# [✓] Frame 208: Crowd detected with 3 people
# [✓] Frame 209: Crowd detected with 5 people
# [✓] Frame 210: Crowd detected with 3 people
# [✓] Logged crowd event at frame 208 with 3 people.
# [✓] Frame 211: Crowd detected with 3 people
# [✓] Frame 212: Crowd detected with 3 people
# [✓] Frame 213: Crowd detected with 3 people
# [✓] Logged crowd event at frame 211 with 3 people.
# [✓] Frame 214: Crowd detected with 3 people
# [✓] Frame 215: Crowd detected with 3 people
# [✓] Frame 216: Crowd detected with 3 people
# [✓] Logged crowd event at frame 214 with 3 people.
# [✓] Frame 217: Crowd detected with 3 people
# [✓] Frame 218: Crowd detected with 3 people
# [✓] Frame 219: Crowd detected with 3 people
# [✓] Logged crowd event at frame 217 with 3 people.
# [✓] Frame 220: Crowd detected with 3 people
# [✓] Frame 221: Crowd detected with 3 people
# [✓] Frame 222: Crowd detected with 3 people
# [✓] Logged crowd event at frame 220 with 3 people.
# [✓] Frame 223: Crowd detected with 3 people
# [✓] Frame 224: Crowd detected with 3 people
# [✓] Frame 225: Crowd detected with 3 people
# [✓] Logged crowd event at frame 223 with 3 people.
# [✓] Frame 226: Crowd detected with 3 people
# [✓] Frame 227: Crowd detected with 3 people
# [✓] Frame 228: Crowd detected with 3 people
# [✓] Logged crowd event at frame 226 with 3 people.
# [✓] Frame 229: Crowd detected with 3 people
# [✓] Frame 230: Crowd detected with 3 people
# [✓] Frame 231: Crowd detected with 3 people
# [✓] Logged crowd event at frame 229 with 3 people.
# [✓] Frame 232: Crowd detected with 5 people
# [✓] Frame 233: Crowd detected with 3 people
# [✓] Frame 234: Crowd detected with 3 people
# [✓] Logged crowd event at frame 232 with 5 people.
# [✓] Frame 235: Crowd detected with 3 people
# [✓] Frame 236: Crowd detected with 3 people
# [✓] Frame 237: Crowd detected with 5 people
# [✓] Logged crowd event at frame 235 with 3 people.
# [✓] Frame 238: Crowd detected with 5 people
# [✓] Frame 239: Crowd detected with 5 people
# [✓] Frame 240: Crowd detected with 5 people
# [✓] Logged crowd event at frame 238 with 5 people.
# [✓] Frame 241: Crowd detected with 5 people
# [✓] Frame 242: Crowd detected with 5 people
# [✓] Frame 243: Crowd detected with 5 people
# [✓] Logged crowd event at frame 241 with 5 people.
# [✓] Frame 244: Crowd detected with 4 people
# [✓] Frame 245: Crowd detected with 4 people
# [✓] Frame 246: Crowd detected with 4 people
# [✓] Logged crowd event at frame 244 with 4 people.
# [✓] Frame 247: Crowd detected with 4 people
# [✓] Frame 248: Crowd detected with 4 people
# [✓] Frame 249: Crowd detected with 4 people
# [✓] Logged crowd event at frame 247 with 4 people.
# [✓] Frame 250: Crowd detected with 4 people
# [✓] Frame 251: Crowd detected with 4 people
# [✓] Frame 252: Crowd detected with 4 people
# [✓] Logged crowd event at frame 250 with 4 people.
# [✓] Frame 253: Crowd detected with 4 people
# [✓] Frame 254: Crowd detected with 4 people
# [✓] Frame 255: Crowd detected with 4 people
# [✓] Logged crowd event at frame 253 with 4 people.
# [✓] Frame 256: Crowd detected with 4 people
# [✓] Frame 257: Crowd detected with 4 people
# [✓] Frame 258: Crowd detected with 4 people
# [✓] Logged crowd event at frame 256 with 4 people.
# [✓] Frame 259: Crowd detected with 4 people
# [✓] Frame 260: Crowd detected with 4 people
# [✓] Frame 261: Crowd detected with 4 people
# [✓] Logged crowd event at frame 259 with 4 people.
# [✓] Frame 262: Crowd detected with 4 people
# [✓] Frame 263: Crowd detected with 4 people
# [✓] Frame 264: Crowd detected with 4 people
# [✓] Logged crowd event at frame 262 with 4 people.
# [✓] Frame 265: Crowd detected with 4 people
# [✓] Frame 266: Crowd detected with 4 people
# [✓] Frame 267: Crowd detected with 5 people
# [✓] Logged crowd event at frame 265 with 4 people.
# [✓] Frame 268: Crowd detected with 4 people
# [✓] Frame 269: Crowd detected with 4 people
# [✓] Frame 270: Crowd detected with 5 people
# [✓] Logged crowd event at frame 268 with 4 people.
# [✓] Frame 271: Crowd detected with 4 people
# [✓] Frame 272: Crowd detected with 5 people
# [✓] Frame 273: Crowd detected with 5 people
# [✓] Logged crowd event at frame 271 with 4 people.
# [✓] Frame 274: Crowd detected with 9 people
# [✓] Frame 275: Crowd detected with 9 people
# [✓] Frame 276: Crowd detected with 9 people
# [✓] Logged crowd event at frame 274 with 9 people.
# [✓] Frame 277: Crowd detected with 9 people
# [✓] Frame 278: Crowd detected with 9 people
# [✓] Frame 279: Crowd detected with 9 people
# [✓] Logged crowd event at frame 277 with 9 people.
# [✓] Frame 280: Crowd detected with 10 people
# [✓] Frame 281: Crowd detected with 6 people
# [✓] Frame 282: Crowd detected with 6 people
# [✓] Logged crowd event at frame 280 with 10 people.
# [✓] Frame 283: Crowd detected with 6 people
# [✓] Frame 284: Crowd detected with 5 people
# [✓] Frame 285: Crowd detected with 5 people
# [✓] Logged crowd event at frame 283 with 6 people.
# [✓] Frame 286: Crowd detected with 5 people
# [✓] Frame 287: Crowd detected with 5 people
# [✓] Frame 288: Crowd detected with 5 people
# [✓] Logged crowd event at frame 286 with 5 people.
# [✓] Frame 289: Crowd detected with 4 people
# [✓] Frame 290: Crowd detected with 4 people
# [✓] Frame 291: Crowd detected with 8 people
# [✓] Logged crowd event at frame 289 with 4 people.
# [✓] Frame 292: Crowd detected with 9 people
# [✓] Frame 293: Crowd detected with 9 people
# [✓] Frame 294: Crowd detected with 6 people
# [✓] Logged crowd event at frame 292 with 9 people.
# [✓] Frame 295: Crowd detected with 5 people
# [✓] Frame 296: Crowd detected with 9 people
# [✓] Frame 297: Crowd detected with 10 people
# [✓] Logged crowd event at frame 295 with 5 people.
# [✓] Frame 298: Crowd detected with 9 people
# [✓] Frame 299: Crowd detected with 5 people
# [✓] Frame 300: Crowd detected with 6 people
# [✓] Logged crowd event at frame 298 with 9 people.
# [✓] Frame 301: Crowd detected with 6 people
# [✓] Frame 302: Crowd detected with 5 people
# [✓] Frame 303: Crowd detected with 5 people
# [✓] Logged crowd event at frame 301 with 6 people.
# [✓] Frame 304: Crowd detected with 6 people
# [✓] Frame 305: Crowd detected with 5 people
# [✓] Frame 306: Crowd detected with 5 people
# [✓] Logged crowd event at frame 304 with 6 people.
# [✓] Frame 307: Crowd detected with 9 people
# [✓] Frame 308: Crowd detected with 10 people
# [✓] Frame 309: Crowd detected with 6 people
# [✓] Logged crowd event at frame 307 with 9 people.
# [✓] Frame 310: Crowd detected with 10 people
# [✓] Frame 311: Crowd detected with 5 people
# [✓] Frame 312: Crowd detected with 6 people
# [✓] Logged crowd event at frame 310 with 10 people.
# [✓] Frame 313: Crowd detected with 6 people
# [✓] Frame 314: Crowd detected with 5 people
# [✓] Frame 315: Crowd detected with 7 people
# [✓] Logged crowd event at frame 313 with 6 people.
# [✓] Frame 316: Crowd detected with 8 people
# [✓] Frame 317: Crowd detected with 7 people
# [✓] Frame 318: Crowd detected with 6 people
# [✓] Logged crowd event at frame 316 with 8 people.
# [✓] Frame 319: Crowd detected with 5 people
# [✓] Frame 320: Crowd detected with 6 people
# [✓] Frame 321: Crowd detected with 6 people
# [✓] Logged crowd event at frame 319 with 5 people.
# [✓] Frame 322: Crowd detected with 6 people
# [✓] Frame 323: Crowd detected with 6 people
# [✓] Frame 324: Crowd detected with 6 people
# [✓] Logged crowd event at frame 322 with 6 people.
# [✓] Frame 325: Crowd detected with 5 people
# [✓] Frame 326: Crowd detected with 5 people
# [✓] Frame 327: Crowd detected with 6 people
# [✓] Logged crowd event at frame 325 with 5 people.
# [✓] Frame 328: Crowd detected with 5 people
# [✓] Frame 329: Crowd detected with 5 people
# [✓] Frame 330: Crowd detected with 6 people
# [✓] Logged crowd event at frame 328 with 5 people.
# [✓] Frame 331: Crowd detected with 5 people
# [✓] Frame 332: Crowd detected with 5 people
# [✓] Frame 333: Crowd detected with 5 people
# [✓] Logged crowd event at frame 331 with 5 people.
# [✓] Frame 334: Crowd detected with 6 people
# [✓] Frame 335: Crowd detected with 6 people
# [✓] Frame 336: Crowd detected with 7 people
# [✓] Logged crowd event at frame 334 with 6 people.
# [✓] Frame 337: Crowd detected with 5 people
# [✓] Frame 338: Crowd detected with 5 people
# [✓] Frame 339: Crowd detected with 5 people
# [✓] Logged crowd event at frame 337 with 5 people.
# [✓] Frame 340: Crowd detected with 5 people
# [✓] Frame 341: Crowd detected with 5 people
# ❌ Failed to read frame.
#
# === Logged Crowd Events ===
# Frame 1 → Crowd Size: 8
# Frame 4 → Crowd Size: 9
# Frame 7 → Crowd Size: 9
# Frame 10 → Crowd Size: 9
# Frame 13 → Crowd Size: 11
# Frame 16 → Crowd Size: 6
# Frame 19 → Crowd Size: 10
# Frame 22 → Crowd Size: 10
# Frame 25 → Crowd Size: 8
# Frame 28 → Crowd Size: 14
# Frame 31 → Crowd Size: 7
# Frame 34 → Crowd Size: 13
# Frame 37 → Crowd Size: 5
# Frame 40 → Crowd Size: 7
# Frame 43 → Crowd Size: 6
# Frame 46 → Crowd Size: 8
# Frame 49 → Crowd Size: 6
# Frame 52 → Crowd Size: 6
# Frame 55 → Crowd Size: 7
# Frame 58 → Crowd Size: 6
# Frame 61 → Crowd Size: 6
# Frame 64 → Crowd Size: 6
# Frame 67 → Crowd Size: 6
# Frame 70 → Crowd Size: 6
# Frame 73 → Crowd Size: 7
# Frame 76 → Crowd Size: 7
# Frame 79 → Crowd Size: 7
# Frame 82 → Crowd Size: 8
# Frame 85 → Crowd Size: 6
# Frame 88 → Crowd Size: 4
# Frame 91 → Crowd Size: 8
# Frame 94 → Crowd Size: 7
# Frame 97 → Crowd Size: 7
# Frame 100 → Crowd Size: 7
# Frame 103 → Crowd Size: 5
# Frame 106 → Crowd Size: 6
# Frame 109 → Crowd Size: 6
# Frame 112 → Crowd Size: 6
# Frame 115 → Crowd Size: 6
# Frame 118 → Crowd Size: 6
# Frame 121 → Crowd Size: 6
# Frame 124 → Crowd Size: 6
# Frame 127 → Crowd Size: 6
# Frame 130 → Crowd Size: 6
# Frame 133 → Crowd Size: 6
# Frame 136 → Crowd Size: 6
# Frame 139 → Crowd Size: 6
# Frame 142 → Crowd Size: 6
# Frame 145 → Crowd Size: 6
# Frame 148 → Crowd Size: 6
# Frame 151 → Crowd Size: 6
# Frame 154 → Crowd Size: 5
# Frame 157 → Crowd Size: 4
# Frame 160 → Crowd Size: 4
# Frame 163 → Crowd Size: 4
# Frame 166 → Crowd Size: 4
# Frame 169 → Crowd Size: 4
# Frame 172 → Crowd Size: 5
# Frame 175 → Crowd Size: 5
# Frame 178 → Crowd Size: 4
# Frame 181 → Crowd Size: 5
# Frame 184 → Crowd Size: 5
# Frame 187 → Crowd Size: 5
# Frame 190 → Crowd Size: 4
# Frame 193 → Crowd Size: 5
# Frame 196 → Crowd Size: 5
# Frame 199 → Crowd Size: 6
# Frame 202 → Crowd Size: 5
# Frame 205 → Crowd Size: 7
# Frame 208 → Crowd Size: 3
# Frame 211 → Crowd Size: 3
# Frame 214 → Crowd Size: 3
# Frame 217 → Crowd Size: 3
# Frame 220 → Crowd Size: 3
# Frame 223 → Crowd Size: 3
# Frame 226 → Crowd Size: 3
# Frame 229 → Crowd Size: 3
# Frame 232 → Crowd Size: 5
# Frame 235 → Crowd Size: 3
# Frame 238 → Crowd Size: 5
# Frame 241 → Crowd Size: 5
# Frame 244 → Crowd Size: 4
# Frame 247 → Crowd Size: 4
# Frame 250 → Crowd Size: 4
# Frame 253 → Crowd Size: 4
# Frame 256 → Crowd Size: 4
# Frame 259 → Crowd Size: 4
# Frame 262 → Crowd Size: 4
# Frame 265 → Crowd Size: 4
# Frame 268 → Crowd Size: 4
# Frame 271 → Crowd Size: 4
# Frame 274 → Crowd Size: 9
# Frame 277 → Crowd Size: 9
# Frame 280 → Crowd Size: 10
# Frame 283 → Crowd Size: 6
# Frame 286 → Crowd Size: 5
# Frame 289 → Crowd Size: 4
# Frame 292 → Crowd Size: 9
# Frame 295 → Crowd Size: 5
# Frame 298 → Crowd Size: 9
# Frame 301 → Crowd Size: 6
# Frame 304 → Crowd Size: 6
# Frame 307 → Crowd Size: 9
# Frame 310 → Crowd Size: 10
# Frame 313 → Crowd Size: 6
# Frame 316 → Crowd Size: 8
# Frame 319 → Crowd Size: 5
# Frame 322 → Crowd Size: 6
# Frame 325 → Crowd Size: 5
# Frame 328 → Crowd Size: 5
# Frame 331 → Crowd Size: 5
# Frame 334 → Crowd Size: 6
# Frame 337 → Crowd Size: 5

# %%
import csv
csv_file = 'crowd_log.csv'
print("\n=== Logged Crowd Events ===")
with open(csv_file, mode='r') as file:
    reader = csv.reader(file)
    header = next(reader)
    for row in reader:
        print(f"Frame {row[0]} → Crowd Size: {row[1]}")
# Out:
# === Logged Crowd Events ===
# Frame 1 → Crowd Size: 8
# Frame 4 → Crowd Size: 9
# Frame 7 → Crowd Size: 9
# Frame 10 → Crowd Size: 9
# Frame 13 → Crowd Size: 11
# Frame 16 → Crowd Size: 6
# Frame 19 → Crowd Size: 10
# Frame 22 → Crowd Size: 10
# Frame 25 → Crowd Size: 8
# Frame 28 → Crowd Size: 14
# Frame 31 → Crowd Size: 7
# Frame 34 → Crowd Size: 13
# Frame 37 → Crowd Size: 5
# Frame 40 → Crowd Size: 7
# Frame 43 → Crowd Size: 6
# Frame 46 → Crowd Size: 8
# Frame 49 → Crowd Size: 6
# Frame 52 → Crowd Size: 6
# Frame 55 → Crowd Size: 7
# Frame 58 → Crowd Size: 6
# Frame 61 → Crowd Size: 6
# Frame 64 → Crowd Size: 6
# Frame 67 → Crowd Size: 6
# Frame 70 → Crowd Size: 6
# Frame 73 → Crowd Size: 7
# Frame 76 → Crowd Size: 7
# Frame 79 → Crowd Size: 7
# Frame 82 → Crowd Size: 8
# Frame 85 → Crowd Size: 6
# Frame 88 → Crowd Size: 4
# Frame 91 → Crowd Size: 8
# Frame 94 → Crowd Size: 7
# Frame 97 → Crowd Size: 7
# Frame 100 → Crowd Size: 7
# Frame 103 → Crowd Size: 5
# Frame 106 → Crowd Size: 6
# Frame 109 → Crowd Size: 6
# Frame 112 → Crowd Size: 6
# Frame 115 → Crowd Size: 6
# Frame 118 → Crowd Size: 6
# Frame 121 → Crowd Size: 6
# Frame 124 → Crowd Size: 6
# Frame 127 → Crowd Size: 6
# Frame 130 → Crowd Size: 6
# Frame 133 → Crowd Size: 6
# Frame 136 → Crowd Size: 6
# Frame 139 → Crowd Size: 6
# Frame 142 → Crowd Size: 6
# Frame 145 → Crowd Size: 6
# Frame 148 → Crowd Size: 6
# Frame 151 → Crowd Size: 6
# Frame 154 → Crowd Size: 5
# Frame 157 → Crowd Size: 4
# Frame 160 → Crowd Size: 4
# Frame 163 → Crowd Size: 4
# Frame 166 → Crowd Size: 4
# Frame 169 → Crowd Size: 4
# Frame 172 → Crowd Size: 5
# Frame 175 → Crowd Size: 5
# Frame 178 → Crowd Size: 4
# Frame 181 → Crowd Size: 5
# Frame 184 → Crowd Size: 5
# Frame 187 → Crowd Size: 5
# Frame 190 → Crowd Size: 4
# Frame 193 → Crowd Size: 5
# Frame 196 → Crowd Size: 5
# Frame 199 → Crowd Size: 6
# Frame 202 → Crowd Size: 5
# Frame 205 → Crowd Size: 7
# Frame 208 → Crowd Size: 3
# Frame 211 → Crowd Size: 3
# Frame 214 → Crowd Size: 3
# Frame 217 → Crowd Size: 3
# Frame 220 → Crowd Size: 3
# Frame 223 → Crowd Size: 3
# Frame 226 → Crowd Size: 3
# Frame 229 → Crowd Size: 3
# Frame 232 → Crowd Size: 5
# Frame 235 → Crowd Size: 3
# Frame 238 → Crowd Size: 5
# Frame 241 → Crowd Size: 5
# Frame 244 → Crowd Size: 4
# Frame 247 → Crowd Size: 4
# Frame 250 → Crowd Size: 4
# Frame 253 → Crowd Size: 4
# Frame 256 → Crowd Size: 4
# Frame 259 → Crowd Size: 4
# Frame 262 → Crowd Size: 4
# Frame 265 → Crowd Size: 4
# Frame 268 → Crowd Size: 4
# Frame 271 → Crowd Size: 4
# Frame 274 → Crowd Size: 9
# Frame 277 → Crowd Size: 9
# Frame 280 → Crowd Size: 10
# Frame 283 → Crowd Size: 6
# Frame 286 → Crowd Size: 5
# Frame 289 → Crowd Size: 4
# Frame 292 → Crowd Size: 9
# Frame 295 → Crowd Size: 5
# Frame 298 → Crowd Size: 9
# Frame 301 → Crowd Size: 6
# Frame 304 → Crowd Size: 6
# Frame 307 → Crowd Size: 9
# Frame 310 → Crowd Size: 10
# Frame 313 → Crowd Size: 6
# Frame 316 → Crowd Size: 8
# Frame 319 → Crowd Size: 5
# Frame 322 → Crowd Size: 6
# Frame 325 → Crowd Size: 5
# Frame 328 → Crowd Size: 5
# Frame 331 → Crowd Size: 5
# Frame 334 → Crowd Size: 6
# Frame 337 → Crowd Size: 5

# %%
from google.colab import files
files.download('crowd_log.csv')
